# %% [markdown]
# # List Creation

# %%
a = []
print(a)
# Out:
# []

# %%
type(a)
# Out:
# list

# %%
b = list()
print(b)
type(b)
# Out:
# []
# list

# %%
a = [1,2,4,5,6,8,9,0]
print(a)
# Out:
# [1, 2, 4, 5, 6, 8, 9, 0]

# %%
type(a)
# Out:
# list

# %% [markdown]
# # Access Items
#
# ## 1) By Indexing

# %%
a
# Out:
# [1, 2, 4, 5, 6, 8, 9, 0]

# %%
# indexing starts from 0
a[0] # Access 1st element of the list
# Out:
# 1

# %%
a[2] # Access 3rd element of the list, index 2
# Out:
# 4

# %%
a[7]
# Out:
# 0

# %% [markdown]
# ### Negative Indexing

# %%
a[-1] # Accessing last element
# Out:
# 0

# %%
a[-2] # Accessing 2nd last element
# Out:
# 9

# %% [markdown]
# # 2) By Slicing

# %%
a[0:3]
# Out:
# [1, 2, 4]

# %%
a[4:7]
# Out:
# [6, 8, 9]

# %%
print(a)
a[0:6:3]
# Out:
# [1, 2, 4, 5, 6, 8, 9, 0]
# [1, 5]

# %%
a[0:5]
# Out:
# [1, 2, 4, 5, 6]

# %%
a[:5]
# Out:
# [1, 2, 4, 5, 6]

# %%
print(a)
a[5:]
# Out:
# [1, 2, 4, 5, 6, 8, 9, 0]
# [8, 9, 0]

# %% [markdown]
# # 3) using `for loop`

# %%
size = len(a)
size
# Out:
# 8

# %%
for i in range(size):
    print(f"a[{i}]: {a[i]}")
# Out:
# a[0]: 1
# a[1]: 2
# a[2]: 4
# a[3]: 5
# a[4]: 6
# a[5]: 8
# a[6]: 9
# a[7]: 0

# %%
for i in a:
    if i%2 == 0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 0

# %% [markdown]
# # Adding element in a List

# %%
b = list() # creating an empty list
print(b)
# Out:
# []

# %%
b.append(55)
b
# Out:
# [55]

# %%
for i in range(2,10):
    b.append(i)

print(b)
# Out:
# [55, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
c = [66,77,88,99,33]
c
# Out:
# [66, 77, 88, 99, 33]

# %%
b.extend(c)
b
# Out:
# [55, 2, 3, 4, 5, 6, 7, 8, 9, 66, 77, 88, 99, 33]

# %%
dir(b)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(a.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
help(a.extend)
# Out:
# Help on built-in function extend:
#
# extend(iterable, /) method of builtins.list instance
#     Extend list by appending elements from the iterable.

# %%
a[1] = 33
a
# Out:
# [1, 33, 4, 5, 6, 8, 9, 0]

# %%
a.remove(1)
a
# Out:
# [33, 4, 5, 6, 8, 9]

# %%
a.sort()
a
# Out:
# [4, 5, 6, 8, 9, 33]

# %%
min(a)
# Out:
# 4
