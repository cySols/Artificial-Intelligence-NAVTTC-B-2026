# %% [markdown]
# # Printing Hello World
# ## using python
#
# This is line 1
#
# This is line 2

# %%
print("Hello world")
# Out:
# Hello world

# %%
a = 22

# %%
print(a)
# Out:
# 22

# %%
b = "hello"

# %%
print(b)
# Out:
# hello

# %%
print(a)
# Out:
# 22

# %% [markdown]
# # List

# %%
a = [1,2,3,4,5]

# %%
print(f"Value of a:{a}, Data type:{type(a)}")
# Out:
# Value of a:[1, 2, 3, 4, 5], Data type:<class 'list'>

# %%
print(f"a[0] = {a[0]}, a[4] = {a[4]}")
# Out:
# a[0] = 1, a[4] = 5

# %% [markdown]
# # Tuple

# %%
b = (2,3,4,5,6)
print(b)
# Out:
# (2, 3, 4, 5, 6)

# %%
b[3]
# Out:
# 5

# %% [markdown]
# # Set

# %%
c = {1,2,3,4,4,5,5}
print(c)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# # String

# %%
d = "hello"
print(d)
# Out:
# hello

# %%
d[0]
# Out:
# 'h'

# %%
d[2]
# Out:
# 'l'

# %% [markdown]
# # Dictionary

# %%
e = {"name": "Ali", "age":12}
print(e)
# Out:
# {'name': 'Ali', 'age': 12}

# %% [markdown]
# # Ordered List
#
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# # unordered List
#
# - First item
# - Second item
# - Third item
